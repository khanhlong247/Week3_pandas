# %% [markdown]
# # Pokemon

# %% [markdown]
# ### Introduction:
#
# This time you will create the data.
#
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Create a data dictionary that looks like the DataFrame below

# %%
data = {'evolution': ['Ivysaur', 'Charmeleon', 'Wartortle', 'Metapod'],
        'hp': [45, 39, 44, 45],
        'name': ['Bulbasaur', 'Charmander', 'Squirtle', 'Caterpie'],
        'type': ['grass', 'fire', 'water', 'bug']}

# %% [markdown]
# ### Step 3. Assign it to a variable called pokemon

# %%
pokemon = pd.DataFrame(data)
pokemon
# Out:
#     evolution  hp        name   type
# 0     Ivysaur  45   Bulbasaur  grass
# 1  Charmeleon  39  Charmander   fire
# 2   Wartortle  44    Squirtle  water
# 3     Metapod  45    Caterpie    bug

# %% [markdown]
# ### Step 4. Ops...it seems the DataFrame columns are in alphabetical order. Place  the order of the columns as name, type, hp, evolution, pokedex

# %%
pokemon = pokemon[['name', 'type', 'hp', 'evolution']]
pokemon
# Out:
#          name   type  hp   evolution
# 0   Bulbasaur  grass  45     Ivysaur
# 1  Charmander   fire  39  Charmeleon
# 2    Squirtle  water  44   Wartortle
# 3    Caterpie    bug  45     Metapod

# %% [markdown]
# ### Step 5. Add another column called place, and insert what you have in mind.

# %%
pokemon['place'] = ['place1', 'place2', 'place3', 'place4']
pokemon
# Out:
# <ipython-input-13-342c6ecbef36>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pokemon['place'] = ['place1', 'place2', 'place3', 'place4']
#          name   type  hp   evolution   place
# 0   Bulbasaur  grass  45     Ivysaur  place1
# 1  Charmander   fire  39  Charmeleon  place2
# 2    Squirtle  water  44   Wartortle  place3
# 3    Caterpie    bug  45     Metapod  place4

# %% [markdown]
# ### Step 6. Present the type of each column

# %%
pokemon.dtypes
# Out:
# name         object
# type         object
# hp            int64
# evolution    object
# place        object
# dtype: object

# %% [markdown]
# ### BONUS: Create your own question and answer it.
